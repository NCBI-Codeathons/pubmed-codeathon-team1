# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
query_df = pd.read_csv('../data/in/team1_search_strats_search_terms.csv')

# %%
query_df.columns
# Out:
# Index(['Query', 'Category', 'Source'], dtype='object')

# %%
dx = query_df.groupby('Category')['Category'].count()

# %%
pieplot = dx.plot.pie(figsize=(10,10),autopct='%1.1f%%', fontsize=18)

# %%
pieplot.get_figure().savefig('../data/visualizations/query_pie.png')
